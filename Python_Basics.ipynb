# %%
#What are programming languagues?
#-->A medium to communicate with machines.
#--->programming languagues are set of instructions that we use to communicate with computers.


#Python
#-->it is a programming languague.
#-->It is a high level languague(easy to understand and similar to english).
#-->It is an interpreted languague.(line by line)
#-->It is case sensitive(This means that uppercase and lowercase letters treated diffrenetly)
a=10
A=20
print(a)
print(A)
# Out:
# 10
# 20

# %%
# comments--->
#1.single line comment ---> #
#2.Multiline comments----> """  """

# %%
#Hey i am user  (this is single line)

""" hey i am a student and
i am learning python"""

print("Hello world")
# Out:
# Hello world

# %%
# What are variables?
# Variables are like containers that store values.

a=10
b=20

# %%
# Rules for declaring the variable!

# 1.It must start with letters(lowercase or uppercase) or underscore(_).
# 2.Can't start with the digits(0 to 9) or any other spl symbols other than undersore(_)
# 3.variables are case sensitive.
# 4.It should not contain any spaces in between.
# 5.We cannot use any keywords as variables(if,else,while etc..)

# %%
abc = 'hi'
print(abc)
# Out:
# hi

# %%
_abc = 10
print(_abc)
# Out:
# 10

# %%
8abg = 10
print(8abg)
# Out:
#   Cell In[10], line 1
#     8abg = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
abc12= 10
print(abc12)
# Out:
# 10

# %%
#Data types
#Integer(int) ---> A numeric value it  can be postive or negative but without decimal point

# %%
age =30
#type() -- it will tell about the datatype of variable holding
print(type(age))

x = -70
print(type(x))
# Out:
# <class 'int'>
# <class 'int'>

# %%
#Float(float) -->numeric value with decimal ppoint(10.5,1.8)

x=10.8
print(type(x))

z=-3.4
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>

# %%
#string(str) --->letters, words, sentences ---anything which is Enclosed in the " " or ' ' then it is String.

# %%
name = "Student"
print(type(name))

a=123
print(type(a))

b="123"
print(type(b))

h="@#$%&*"
print(type(h))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>

# %%
#Boolean (bool)---> These are like yes or no answers.
#it will  have only two things (True or False).

# %%
is_raining = True
print(type(is_raining))
# Out:
# <class 'bool'>

# %%
is_raining=False
print(type(is_raining))
# Out:
# <class 'bool'>

# %%
#Operators ---> Operators are the symbols that perform operations on values

a=10
b=5
print(a+b)
#operators  --->+
#operands ---->a,b

#Arthmetic operators

#Addition   --->+
#subtraction --->-
#Multiplication---> *
#division  ---> /   (division operator will always going to give the float value as the output)
#floor division ---> //  (floor division will always going to give int value as the output)
#modulous ---->(Reminder) %
#exponentional --> **
# Out:
# 15

# %%
a=10
b=5

print(a+b)
print(a-b)
print(a*b)   #10 x 5 =50
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
#comparision operator--->it going to give the output in boolean(True or False)
#We r going to comapre two values.

num1=10
num2=20

print(num1>num2)
print(num1<num2)
print(num1==num2)  #== will check for bothsides are equal or not if equal it will giving true
print(num1!=num2)  #!= will check for diff values on bothsides if diff it will give true.
print(num1>=num2)  #
print(num1<=num2)
# Out:
# False
# True
# False
# True
# False
# True

# %%
#Assignment operator
a=10

# a=a+5
# print(a)

#shortform of a=a+5
a+=5
print(a)
# Out:
# 15

# %%
#Logical operators

#Helps to make desicions

#and,or,not

# and ---> When both conditions are satisfied then the output will be true , else false.
# or ---> when atleast one codition is satisfied then the output will be true , else false.
#not --> Reversing

# %%
#and
print(5>3 and 6>4)
print(5>3 and 5==50)
print(5<3 and 5==50)
# Out:
# True
# False
# False

# %%
#or
print(5>3 or 5==50)
print(5>10 or 5==67)
# Out:
# True
# False

# %%
#not
a=True
print(not(a))

b=False
print(not(b))
# Out:
# False
# True

# %%
#Sequential datatypes :- Sequential datatypes are the Datatypes where elemnets are stored in a sequence.
#we can store multiple values with multiple datatypes.
#Elements are stored ina fixed order
#List :ordered , mutable(changable), allow dupliactes
#tuple :ordered, immutable (we cant change)

# %%
#list
#we can create list using []

# %%
a=[10,20,30,"Student","India",89.8]
print(type(a))
print(a[4])
print(a[5])

print(a[-3])
print(a[-1])
print(a[5])
# Out:
# <class 'list'>
# India
# 89.8
# Student
# 89.8
# 89.8

# %%
#Slicing---> when u want to extract any specific part from whole we will be using slicing.
#Syntax -->variablename[startindex :endindex+1]

#syntax with step ---->variablename[startindex : endindex+1 :stepcount+1]

# %%
lst = [10,20,30,40,50,60,70]

#if i want from 20 - 50
print(lst[1:5])

#10-40
print(lst[0:4])

#30-50
print(lst[2:5])

#20-60
print(lst[1:6])
# Out:
# [20, 30, 40, 50]
# [10, 20, 30, 40]
# [30, 40, 50]
# [20, 30, 40, 50, 60]

# %%
a= [10 , 20 , "Tarun" , "sony" , "Nishkarsh" , 50 , 80.4]

#output --->20,sony,50
#20-50
print(a[1:6:2])

# i want output as 10 and tarun
print(a[0:3:2])
# Out:
# [20, 'sony', 50]
# [10, 'Tarun']

# %%
b = ["Tarun" , "Sony" , "Nishkarsh" , "Dipansh" , "Raghavendra" , "Dilya"]

#from tarun to raghavendra
#i want only tarun,nishkarsh,raghavendra

print(b[0:5:2])
# Out:
# ['Tarun', 'Nishkarsh', 'Raghavendra']

# %%
#Methods in the list

#append() ---> will add the elemenet to the end of the list
b.append("Karthik")
print(b)
# Out:
# ['Tarun', 'Sony', 'Nishkarsh', 'Dipansh', 'Raghavendra', 'Dilya', 'Karthik']

# %%
#insert() --> will add the elment in the specific position
b.insert(2,"Saran")
print(b)
# Out:
# ['Tarun', 'Sony', 'Saran', 'Nishkarsh', 'Dipansh', 'Raghavendra', 'Dilya', 'Karthik']

# %%
b.insert(0,"Kapil")
print(b)
# Out:
# ['Kapil', 'Tarun', 'Sony', 'Saran', 'Nishkarsh', 'Dipansh', 'Raghavendra', 'Dilya', 'Karthik']

# %%
b[4] = "Varun"
print(b)
# Out:
# ['Kapil', 'Tarun', 'Sony', 'Saran', 'Varun', 'Dipansh', 'Raghavendra', 'Dilya', 'Karthik']

# %%
#pop() --->will remove the elements.(by default it will remove the last element)
b.pop()
print(b)
# Out:
# ['Kapil', 'Tarun', 'Sony', 'Saran', 'Varun', 'Dipansh', 'Raghavendra', 'Dilya']

# %%
#pop(index number)
b.pop(0)
print(b)
# Out:
# ['Tarun', 'Sony', 'Saran', 'Varun', 'Dipansh', 'Raghavendra', 'Dilya']

# %%
#Tuple -->ordered
#Immutable , allow duplicates
#Will be declared using ()

# %%
tup = (20 , "Tarun" , "Sony" , "Nishkarsh" , "Karthik" , 89.0 , "Tarun")
print(type(tup))
# Out:
# <class 'tuple'>

# %%
tup[2]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 tup[2]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Tuple methods

tup = (20 , "Tarun" , "Sony" , "Nishkarsh" , "Karthik" , 89.0 , "Tarun")
print(tup)

#count() ----> used to count the number of occurences of the element
print(tup.count("Tarun"))

#index() ---> it will be giving the index nuber of the element
print(tup.index(89.0))
# Out:
# (20, 'Tarun', 'Sony', 'Nishkarsh', 'Karthik', 89.0, 'Tarun')
# 2
# 5

# %%
#Non- Sequnential Datatypes ---->These are the Datatyppes where the elements do not have any specific index numbers .
# and we cannot extract the elements by using index numbers.

# %%
#Set
#we going to create set using {}
#unoredred
#set is mutable
#you can only add and delete elemnets
#it will not allow any duplicates.

# %%
s={10,20,30,10,20}
print(s)
print(type(s))
# Out:
# {10, 20, 30}
# <class 'set'>

# %%
print(s[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 print(s[1])
#
# TypeError: 'set' object is not subscriptable

# %%
#Methods in set
#add() --->it will add the element in the set

s.add("Tarun")
print(s)
# Out:
# {'Tarun', 10, 20, 30}

# %%
s.add("Bob")
print(s)
# Out:
# {'Bob', 10, 20, 'Tarun', 30}

# %%
#Remove() --->we can remove by using elemnet
s.remove("Tarun")
print(s)
# Out:
# {'Bob', 10, 20, 30}

# %%
#pop() -->it will remove the random element
s.pop()
print(s)
# Out:
# {10, 20, 30}
