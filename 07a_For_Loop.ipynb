# %%
#loops

#types of loops
#1.For loop --->Runs for know number of times
#2.While loop  ---Runs until te condition become false

# %%
#for variable in range(start,end)
    #code to repeat

# %%
#print hello world 5 times

print("Hello world")
print("Hello world")
print("Hello world")
print("Hello world")
print("Hello world")
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world

# %%
for i in range(1,6):
  print("Hello world")
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world

# %%
for i in range(0,5):
  print(i)
  print("Good mrng")
# Out:
# 0
# Good mrng
# 1
# Good mrng
# 2
# Good mrng
# 3
# Good mrng
# 4
# Good mrng

# %%
for shiv in range(10,20):
  print(shiv,"good morning")
# Out:
# 10 good morning
# 11 good morning
# 12 good morning
# 13 good morning
# 14 good morning
# 15 good morning
# 16 good morning
# 17 good morning
# 18 good morning
# 19 good morning
