# %%
#2.While loop  ---Runs until the condition become false
#works with increment

#print 1 to 5

i =1
while i<=5:
  print(i)
  i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
status = "run"

while status=="run":
  print("I can do more")
  status= str(input("Enter the status"))
# Out:
# I can do more
